# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = [1.00, 1.00, 1.00, 0.75, 0.80, 0.83, 0.86, 0.88, 0.89, 0.90, 0.82, 0.83, 0.85, 0.86, 0.87, 0.88, 0.88, 0.89, 0.89, 0.90, 
0.90, 0.91, 0.91, 0.92, 0.92, 0.88, 0.89, 0.89, 0.90, 0.90, 0.90, 0.88, 0.85, 0.85, 0.83, 0.81, 0.81, 0.82, 0.79, 0.77, 
0.78, 0.79, 0.79, 0.80, 0.80, 0.80, 0.81, 0.81, 0.82, 0.82, 0.80, 0.81, 0.81, 0.81, 0.82, 0.82, 0.82, 0.81, 0.81, 0.82, 
0.82, 0.82, 0.83, 0.83, 0.83, 0.83, 0.84, 0.84, 0.84, 0.84, 0.85, 0.83, 0.84, 0.84, 0.84, 0.84, 0.84, 0.85, 0.85, 0.85, 
0.85, 0.85, 0.84, 0.83, 0.84, 0.84, 0.84, 0.84, 0.84, 0.83, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.85, 0.85, 0.85, 0.85, 
0.85, 0.85, 0.85, 0.85, 0.84, 0.84, 0.84, 0.84, 0.84, 0.85, 0.84, 0.84, 0.84, 0.84, 0.83, 0.84, 0.84, 0.84, 0.84, 0.84, 
0.84, 0.84, 0.84, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.82, 0.81, 0.82, 0.82, 0.82, 0.81, 0.81, 
0.82, 0.82, 0.82, 0.82, 0.81, 0.82, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 
0.81, 0.80, 0.80, 0.80, 0.81, 0.80, 0.80, 0.80, 0.80, 0.81, 0.81, 0.81, 0.81, 0.80, 0.81, 0.80, 0.80, 0.80, 0.80, 0.80, 
0.80, 0.80, 0.80, 0.80, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.82, 0.82, 0.82, 0.82, 0.81, 0.81, 
0.82, 0.82, 0.82, 0.82, 0.82, 0.82, 0.81, 0.81, 0.81, 0.81, 0.82, 0.82, 0.82, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 
0.81, 0.82, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.82, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 
0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 
0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.80, 0.80, 0.81, 0.81, 0.81, 0.81, 
0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 
0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.82, 0.82, 
0.82, 0.82, 0.82, 0.82, 0.82, 0.82, 0.82, 0.82, 0.82, 0.82, 0.82, 0.82, 0.82, 0.82, 0.82, 0.82, 0.82, 0.82, 0.82, 0.82, 
0.82, 0.82, 0.83, 0.83, 0.83, 0.83, 0.82, 0.82, 0.83, 0.83, 0.82, 0.82, 0.82, 0.82, 0.83, 0.83, 0.83, 0.82, 0.82, 0.82, 
0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.82, 0.83, 0.83, 0.83, 
0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 
0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 
0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 
0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 
0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 
0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83]

np.save("4aps", data)

# %%
x_range = list(range(500))
# plt.plot(x_range, data, )
# plt.savefig("4aps_graph")
# plt.show()

# %%
data1 = np.load("1aps.npy")
data2 = np.load("2aps.npy")
data3 = np.load("3aps.npy")
data4 = np.load("4aps.npy")
data5 = np.load("5aps.npy")

plt.plot(x_range, data1, label="1 Node")
plt.plot(x_range, data2, label="2 Nodes")
plt.plot(x_range, data3, label="3 Nodes")
plt.plot(x_range, data4, label="4 Nodes")
plt.plot(x_range, data5, label="5 Nodes")
# plt.legend(bbox_to_anchor=(1, 1), loc=2, title="Available APs")
plt.title("Probability of finding an access point")
plt.ylabel("Probability")
plt.xlabel("Trial")
plt.savefig("final_graph")
plt.show()

# %%
probs = [.28, .57, .72, .83, .87]
nodes = [1, 2, 3, 4, 5]

A,B = np.polyfit(np.log(nodes), probs, 1)
xs = np.arange(.5, 6.0, .02)

def f(A, B, x):
    return A + B*np.log(x)

print(A, B)
plt.plot(nodes, probs, "ro", xs, f(B, A, xs))
plt.title("Probability Trend")
plt.ylabel("Probability")
plt.xlabel("# of APs")
plt.savefig("prob_trend")
plt.show()
# Out:
# (0.37506318484699547, 0.29487761990469463)
